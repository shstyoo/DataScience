# %%
# %matplotlib inline

import pandas as pd

import matplotlib
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="white", color_codes=True)

avg_stats_all = pd.read_json('results_core_validated.json', convert_axes=True)

# %%
avg_stats_all
# Out:
#                    ana  bastion      dva    genji    hanzo  junkrat    lucio  \
# BRONZE MEDALS     0.45     0.90     0.79     0.81     0.71     0.73     0.49
# CRITICAL HITS      NaN     6.00     8.70     7.40     7.00      NaN     6.50
# DAMAGE         2016.00  7367.00  5155.00  4983.00  5559.00  6832.00  2481.00
# DEATHS            4.95     6.24     5.26     6.66     5.83     6.67     6.12
# E:D RATIO         1.14     2.36     2.70     2.09     2.19     2.04     1.59
# GOLD MEDALS       0.62     1.33     1.10     0.76     0.83     0.96     1.53
# HEALING        3276.00   601.00      NaN      NaN      NaN      NaN  6338.00
# MEDALS            1.75     3.34     2.84     2.38     2.31     2.52     2.61
# OBJ KILLS         1.99     5.62     5.26     4.09     4.21     4.95     5.16
# OBJ TIME         29.00    15.00    55.00    32.00    17.00    22.00    65.00
# SILVER MEDALS     0.69     1.12     0.96     0.82     0.77     0.82     0.59
# SOLO KILLS         NaN     3.39      NaN     3.32     3.49     3.73      NaN
# VOTING CARDS      0.20     0.40     0.28     0.31     0.19     0.25     0.60
# WEAPON ACC       13.00    23.00    26.00    28.00    21.00    19.00    24.00
#
#                 mccree      mei    mercy    ...     reinhardt  roadhog  \
# BRONZE MEDALS     0.77     1.06     0.25    ...          0.65     0.86
# CRITICAL HITS     3.90    17.60     9.40    ...           NaN    13.90
# DAMAGE         5305.00  3516.00   408.00    ...       3685.00  5905.00
# DEATHS            7.04     6.10     5.42    ...          6.78     6.06
# E:D RATIO         2.07     2.15     0.26    ...          1.45     2.42
# GOLD MEDALS       0.82     0.89     0.97    ...          0.82     1.29
# HEALING            NaN   707.00  5233.00    ...           NaN  2783.00
# MEDALS            2.38     3.09     1.45    ...          2.14     3.77
# OBJ KILLS         4.41     5.33     0.46    ...          3.49     5.36
# OBJ TIME         24.00    46.00    25.00    ...         65.00    42.00
# SILVER MEDALS     0.79     1.14     0.23    ...          0.67     1.63
# SOLO KILLS        3.85      NaN     0.13    ...          1.78      NaN
# VOTING CARDS      0.33     0.26     0.53    ...          0.49     0.47
# WEAPON ACC       38.00    33.00    27.00    ...           NaN    32.00
#
#                soldier76  symmetra  torbjorn   tracer  widowmaker  winston  \
# BRONZE MEDALS       0.98      0.73      0.69     0.77        0.68     0.82
# CRITICAL HITS       4.90       NaN      5.50     7.10       11.60      NaN
# DAMAGE           6446.00   3265.00   5928.00  5147.00     4798.00  4110.00
# DEATHS              6.58      4.70      4.54     7.01        5.08     7.44
# E:D RATIO           2.43      2.48      3.32     2.28        2.58     1.99
# GOLD MEDALS         1.41      0.65      1.19     0.99        0.66     0.86
# HEALING          1081.00       NaN       NaN      NaN         NaN      NaN
# MEDALS              3.79      2.11      2.78     2.63        2.01     2.56
# OBJ KILLS           6.19      3.93      5.33     5.64        3.09     5.51
# OBJ TIME           36.00     14.00     12.00    37.00        7.00    57.00
# SILVER MEDALS       1.40      0.73      0.90     0.87        0.67     0.88
# SOLO KILLS           NaN      1.79       NaN     3.32        4.19     2.18
# VOTING CARDS        0.34      0.60      0.60     0.26        0.22     0.22
# WEAPON ACC         34.00       NaN     25.00    29.00       34.00      NaN
#
#                  zarya  zenyatta
# BRONZE MEDALS     0.75      0.73
# CRITICAL HITS      NaN      7.60
# DAMAGE         5048.00   3560.00
# DEATHS            5.25      5.87
# E:D RATIO         2.64      1.64
# GOLD MEDALS       1.14      1.06
# HEALING            NaN   3441.00
# MEDALS            2.82      2.64
# OBJ KILLS         6.45      3.75
# OBJ TIME         58.00     31.00
# SILVER MEDALS     0.93      0.85
# SOLO KILLS         NaN       NaN
# VOTING CARDS      0.58      0.56
# WEAPON ACC       42.00     26.00
#
# [14 rows x 22 columns]

# %%
df = avg_stats_all.iloc[[2]]
df.plot(kind='bar')
